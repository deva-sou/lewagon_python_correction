# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# # Get competitor's products and prices info

# %% [markdown]
# Naturalia is a health food French company, and one of the main competitors of Greenweez.
#
# In this challenge, you will gather information on Naturalia products to help Greenweez drive its pricing strategy.

# %% [markdown]
# ## Naturalia website

# %% [markdown]
# ### BeautifulSoup

# %% [markdown]
# Go to the [website](https://www.naturalia.fr/catalogsearch/result/?q=compote) and study the url. What is the endpoint? What is the query parameter ?

# %% [markdown]
# > **Your Answer Here (Double click)**

# %% [markdown]
# Using `requests` and `bs4`libraries, convert the html code to a BeautifulSoup object and store it in a `soup`variable.
#
# Have a look at the lecture if you're unsure about the syntax.

# %%
#your code here
import requests
from bs4 import BeautifulSoup

url='https://www.naturalia.fr/catalogsearch/result/?q=compote'

response=requests.get(url)
soup=BeautifulSoup(response.text,"html.parser")

# %% [markdown]
# ### Investigating the page layout

# %% [markdown]
# We want to get information about all the products displayed on the page.
#
# By examining the website's HTML code, determine the HTML tag that contains information for each product.

# %% [markdown]
# > **Your Answer Here (Double click)**

# %% [markdown]
# Use BeautifulSoup's `find_all()` method to retrieve all **li** tags with the class **item product product-item** and store the results in a variable named `items`.
#
# Have a look at the lecture for guidance.

# %%
#your code here
items=soup.find_all('li',{"class":"item product product-item"})
items
# Out:
# [<li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/puree-pommes-fruit-rouge-705g">
#                                      Purée de Pommes et fruits rouges 705g Bio							</a>
#  </p>
#  <p class="product-item-brand">Naturalia</p>
#  <div class="product-item-photo">
#  <p class="banner discount percent-15">-15%</p>
#  <a class="product photo" href="https://www.naturalia.fr/puree-pommes-fruit-rouge-705g" tabindex="-1">
#  <span class="product-image-container product-image-container-58849">
#  <span class="product-image-wrapper">
#  <img alt="Purée de Pommes et fruits rouges 705g Bio" class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/3/7/3700036907065.p1-1500j.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-58849 {
#      width: 233px;
#  }
#  .product-image-container-58849 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-58849");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-58849  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-58849" data-product-id="58849" data-role="priceBox">
#  <span class="special-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix Spécial</span>
#  <span class="price-wrapper" data-price-amount="4.95" data-price-type="finalPrice" id="product-price-58849"><span class="price">4,95 €</span></span>
#  </span>
#  </span>
#  <span class="old-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix normal</span>
#  <span class="price-wrapper" data-price-amount="5.85" data-price-type="oldPrice" id="old-price-58849"><span class="price">5,85 €</span></span>
#  </span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58849,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      7,02 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="58849"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-58849'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-58849" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-58849'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58849,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/puree-de-cacahuetes-350g">
#                                      Purée de cacahuètes 350g Bio							</a>
#  </p>
#  <p class="product-item-brand">Naturalia</p>
#  <div class="product-item-photo">
#  <a class="product photo" href="https://www.naturalia.fr/puree-de-cacahuetes-350g" tabindex="-1">
#  <span class="product-image-container product-image-container-96559">
#  <span class="product-image-wrapper">
#  <img alt="Purée de cacahuètes 350g Bio" class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/0/3/03700036907683_a1c1.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-96559 {
#      width: 233px;
#  }
#  .product-image-container-96559 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-96559");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-96559  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="product-reviews-summary short">
#  <div class="rating-summary">
#  <span class="label"><span>Évaluation:</span></span>
#  <div class="rating-result" id="rating-result_96559" title="5 étoiles">
#  <span><span>100%</span></span>
#  </div>
#  <script type="text/javascript">var elem2VQ3wZjm = document.querySelector('#rating-result_96559 span');
#  if (elem2VQ3wZjm) {
#  elem2VQ3wZjm.style.width = '100%';
#  }</script> </div>
#  <div class="reviews-actions">
#  <a class="action view" href="https://www.naturalia.fr/puree-de-cacahuetes-350g#reviews">1                 <span>Avis                </span>
#  </a>
#  </div>
#  </div>
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-96559" data-product-id="96559" data-role="priceBox">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-wrapper" data-price-amount="5" data-price-type="finalPrice" id="product-price-96559"><span class="price">5,00 €</span></span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":96559,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      16,67 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="96559"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-96559'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-96559" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-96559'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":96559,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/grde-cerise-120g">
#                                      Gourde de Cerise dès 6M 120g Bio							</a>
#  </p>
#  <p class="product-item-brand">Popote</p>
#  <div class="product-item-photo">
#  <p class="banner discount percent-15">-16%</p>
#  <a class="product photo" href="https://www.naturalia.fr/grde-cerise-120g" tabindex="-1">
#  <span class="product-image-container product-image-container-58143">
#  <span class="product-image-wrapper">
#  <img alt="Gourde de Cerise dès 6M 120g Bio" class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/3/7/3760262840239.p1-1500j.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-58143 {
#      width: 233px;
#  }
#  .product-image-container-58143 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-58143");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-58143  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-58143" data-product-id="58143" data-role="priceBox">
#  <span class="special-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix Spécial</span>
#  <span class="price-wrapper" data-price-amount="2.45" data-price-type="finalPrice" id="product-price-58143"><span class="price">2,45 €</span></span>
#  </span>
#  </span>
#  <span class="old-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix normal</span>
#  <span class="price-wrapper" data-price-amount="2.9" data-price-type="oldPrice" id="old-price-58143"><span class="price">2,90 €</span></span>
#  </span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58143,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      20,42 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="58143"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-58143'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-58143" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-58143'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58143,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/gourde-puree-pomme-120g">
#                                      Purée de pommes en gourde 120g Bio							</a>
#  </p>
#  <p class="product-item-brand">Popote</p>
#  <div class="product-item-photo">
#  <p class="banner discount percent-15">-17%</p>
#  <a class="product photo" href="https://www.naturalia.fr/gourde-puree-pomme-120g" tabindex="-1">
#  <span class="product-image-container product-image-container-94497">
#  <span class="product-image-wrapper">
#  <img alt="Purée de pommes en gourde 120g Bio " class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/0/3/03760262840321_a1c1.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-94497 {
#      width: 233px;
#  }
#  .product-image-container-94497 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-94497");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-94497  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-94497" data-product-id="94497" data-role="priceBox">
#  <span class="special-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix Spécial</span>
#  <span class="price-wrapper" data-price-amount="1.45" data-price-type="finalPrice" id="product-price-94497"><span class="price">1,45 €</span></span>
#  </span>
#  </span>
#  <span class="old-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix normal</span>
#  <span class="price-wrapper" data-price-amount="1.75" data-price-type="oldPrice" id="old-price-94497"><span class="price">1,75 €</span></span>
#  </span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":94497,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      12,08 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="94497"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-94497'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-94497" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-94497'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":94497,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/gourde-puree-carotte-120g">
#                                      Purée de carotte en gourde 120g Bio							</a>
#  </p>
#  <p class="product-item-brand">Popote</p>
#  <div class="product-item-photo">
#  <p class="banner discount percent-15">-16%</p>
#  <a class="product photo" href="https://www.naturalia.fr/gourde-puree-carotte-120g" tabindex="-1">
#  <span class="product-image-container product-image-container-94501">
#  <span class="product-image-wrapper">
#  <img alt="Purée de carotte en gourde 120g Bio " class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/0/3/03760262840130_a1c1.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-94501 {
#      width: 233px;
#  }
#  .product-image-container-94501 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-94501");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-94501  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-94501" data-product-id="94501" data-role="priceBox">
#  <span class="special-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix Spécial</span>
#  <span class="price-wrapper" data-price-amount="1.55" data-price-type="finalPrice" id="product-price-94501"><span class="price">1,55 €</span></span>
#  </span>
#  </span>
#  <span class="old-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix normal</span>
#  <span class="price-wrapper" data-price-amount="1.85" data-price-type="oldPrice" id="old-price-94501"><span class="price">1,85 €</span></span>
#  </span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":94501,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      12,92 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="94501"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-94501'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-94501" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-94501'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":94501,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/gourde-puree-banane-120g">
#                                      Purée de banane en gourde 120g Bio							</a>
#  </p>
#  <p class="product-item-brand">Popote</p>
#  <div class="product-item-photo">
#  <p class="banner discount percent-15">-17%</p>
#  <a class="product photo" href="https://www.naturalia.fr/gourde-puree-banane-120g" tabindex="-1">
#  <span class="product-image-container product-image-container-94499">
#  <span class="product-image-wrapper">
#  <img alt="Purée de banane en gourde 120g Bio " class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/0/3/03760262840314_a1c1.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-94499 {
#      width: 233px;
#  }
#  .product-image-container-94499 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-94499");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-94499  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-94499" data-product-id="94499" data-role="priceBox">
#  <span class="special-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix Spécial</span>
#  <span class="price-wrapper" data-price-amount="1.45" data-price-type="finalPrice" id="product-price-94499"><span class="price">1,45 €</span></span>
#  </span>
#  </span>
#  <span class="old-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix normal</span>
#  <span class="price-wrapper" data-price-amount="1.75" data-price-type="oldPrice" id="old-price-94499"><span class="price">1,75 €</span></span>
#  </span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":94499,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      12,08 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="94499"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-94499'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-94499" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-94499'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":94499,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/grde-mirabelles-120g">
#                                      Gourde de Mirabelle dès 6M 120g Bio							</a>
#  </p>
#  <p class="product-item-brand">Popote</p>
#  <div class="product-item-photo">
#  <p class="banner discount percent-15">-16%</p>
#  <a class="product photo" href="https://www.naturalia.fr/grde-mirabelles-120g" tabindex="-1">
#  <span class="product-image-container product-image-container-58147">
#  <span class="product-image-wrapper">
#  <img alt="Gourde de Mirabelle dès 6M 120g Bio" class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/3/7/3760262840451.p1-1500j.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-58147 {
#      width: 233px;
#  }
#  .product-image-container-58147 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-58147");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-58147  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-58147" data-product-id="58147" data-role="priceBox">
#  <span class="special-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix Spécial</span>
#  <span class="price-wrapper" data-price-amount="2.3" data-price-type="finalPrice" id="product-price-58147"><span class="price">2,30 €</span></span>
#  </span>
#  </span>
#  <span class="old-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix normal</span>
#  <span class="price-wrapper" data-price-amount="2.75" data-price-type="oldPrice" id="old-price-58147"><span class="price">2,75 €</span></span>
#  </span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58147,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      19,17 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="58147"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-58147'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-58147" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-58147'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58147,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/grd-peche-120g">
#                                      Gourde de Pêche dès 4M 120g Bio							</a>
#  </p>
#  <p class="product-item-brand">Popote</p>
#  <div class="product-item-photo">
#  <p class="banner discount percent-15">-17%</p>
#  <a class="product photo" href="https://www.naturalia.fr/grd-peche-120g" tabindex="-1">
#  <span class="product-image-container product-image-container-58146">
#  <span class="product-image-wrapper">
#  <img alt="Gourde de Pêche dès 4M 120g Bio" class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/3/7/3760262840468.p1-1500j.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-58146 {
#      width: 233px;
#  }
#  .product-image-container-58146 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-58146");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-58146  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-58146" data-product-id="58146" data-role="priceBox">
#  <span class="special-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix Spécial</span>
#  <span class="price-wrapper" data-price-amount="1.9" data-price-type="finalPrice" id="product-price-58146"><span class="price">1,90 €</span></span>
#  </span>
#  </span>
#  <span class="old-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix normal</span>
#  <span class="price-wrapper" data-price-amount="2.29" data-price-type="oldPrice" id="old-price-58146"><span class="price">2,29 €</span></span>
#  </span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58146,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      15,83 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="58146"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-58146'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-58146" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-58146'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58146,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/grde-figue-120g">
#                                      Gourde de Figue dès 6M 120g Bio							</a>
#  </p>
#  <p class="product-item-brand">Popote</p>
#  <div class="product-item-photo">
#  <p class="banner discount percent-15">-16%</p>
#  <a class="product photo" href="https://www.naturalia.fr/grde-figue-120g" tabindex="-1">
#  <span class="product-image-container product-image-container-58145">
#  <span class="product-image-wrapper">
#  <img alt="Gourde de Figue dès 6M 120g Bio" class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/3/7/3760262840215.p1-1500j.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-58145 {
#      width: 233px;
#  }
#  .product-image-container-58145 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-58145");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-58145  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-58145" data-product-id="58145" data-role="priceBox">
#  <span class="special-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix Spécial</span>
#  <span class="price-wrapper" data-price-amount="2.3" data-price-type="finalPrice" id="product-price-58145"><span class="price">2,30 €</span></span>
#  </span>
#  </span>
#  <span class="old-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix normal</span>
#  <span class="price-wrapper" data-price-amount="2.75" data-price-type="oldPrice" id="old-price-58145"><span class="price">2,75 €</span></span>
#  </span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58145,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      19,17 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="58145"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-58145'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-58145" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-58145'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58145,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/grde-framboise-120g">
#                                      Gourde de Framboise dès 6M 120g Bio							</a>
#  </p>
#  <p class="product-item-brand">Popote</p>
#  <div class="product-item-photo">
#  <p class="banner discount percent-15">-16%</p>
#  <a class="product photo" href="https://www.naturalia.fr/grde-framboise-120g" tabindex="-1">
#  <span class="product-image-container product-image-container-58142">
#  <span class="product-image-wrapper">
#  <img alt="Gourde de Framboise dès 6M 120g Bio" class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/3/7/3760262840253.p1-1500j.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-58142 {
#      width: 233px;
#  }
#  .product-image-container-58142 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-58142");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-58142  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-58142" data-product-id="58142" data-role="priceBox">
#  <span class="special-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix Spécial</span>
#  <span class="price-wrapper" data-price-amount="2.4" data-price-type="finalPrice" id="product-price-58142"><span class="price">2,40 €</span></span>
#  </span>
#  </span>
#  <span class="old-price">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-label">Prix normal</span>
#  <span class="price-wrapper" data-price-amount="2.85" data-price-type="oldPrice" id="old-price-58142"><span class="price">2,85 €</span></span>
#  </span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58142,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      20,00 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="58142"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-58142'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-58142" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-58142'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58142,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
# ...
#  <div class="price-box price-final_price" data-price-box="product-id-52783" data-product-id="52783" data-role="priceBox">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-wrapper" data-price-amount="5.25" data-price-type="finalPrice" id="product-price-52783"><span class="price">5,25 €</span></span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":52783,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      13,12 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="52783"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-52783'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-52783" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-52783'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":52783,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/puree-pommes-705g">
#                                      Purée de pommes sans sucres ajoutés 705G Bio							</a>
#  </p>
#  <p class="product-item-brand">Naturalia</p>
#  <div class="product-item-photo">
#  <p class="banner prix_bas"></p>
#  <a class="product photo" href="https://www.naturalia.fr/puree-pommes-705g" tabindex="-1">
#  <span class="product-image-container product-image-container-47184">
#  <span class="product-image-wrapper">
#  <img alt="Purée de pommes sans sucres ajoutés 705G Bio" class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/d/i/diapositive9.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-47184 {
#      width: 233px;
#  }
#  .product-image-container-47184 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-47184");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-47184  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-47184" data-product-id="47184" data-role="priceBox">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-wrapper" data-price-amount="3.25" data-price-type="finalPrice" id="product-price-47184"><span class="price">3,25 €</span></span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":47184,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      4,61 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="47184"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-47184'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-47184" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-47184'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":47184,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/puree-pommes-poires-705g">
#                                      Purée Pommes Poires sans sucres ajoutés 705G Bio							</a>
#  </p>
#  <p class="product-item-brand">Naturalia</p>
#  <div class="product-item-photo">
#  <a class="product photo" href="https://www.naturalia.fr/puree-pommes-poires-705g" tabindex="-1">
#  <span class="product-image-container product-image-container-47185">
#  <span class="product-image-wrapper">
#  <img alt="Puree Pommes Poires 705G Bio" class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/d/i/diapositive10.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-47185 {
#      width: 233px;
#  }
#  .product-image-container-47185 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-47185");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-47185  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-47185" data-product-id="47185" data-role="priceBox">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-wrapper" data-price-amount="3.99" data-price-type="finalPrice" id="product-price-47185"><span class="price">3,99 €</span></span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":47185,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      5,66 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="47185"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-47185'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-47185" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-47185'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":47185,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
#  <p class="product name product-item-name">
#  <a class="product-item-link" href="https://www.naturalia.fr/puree-pomme-poire-1-05kg">
#                                      Compote Pomme Poire Maxi Format 1.050kg Bio							</a>
#  </p>
#  <p class="product-item-brand">Danival</p>
#  <div class="product-item-photo">
#  <a class="product photo" href="https://www.naturalia.fr/puree-pomme-poire-1-05kg" tabindex="-1">
#  <span class="product-image-container product-image-container-55605">
#  <span class="product-image-wrapper">
#  <img alt="Compote Pomme Poire Maxi Format 1.050kg Bio" class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/3/4/3431590014387.p1-1500j.jpg" width="233"/></span>
#  </span>
#  <style>.product-image-container-55605 {
#      width: 233px;
#  }
#  .product-image-container-55605 span.product-image-wrapper {
#      padding-bottom: 100%;
#  }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-55605");
#  for (var i = 0; i < prodImageContainers.length; i++) {
#      prodImageContainers[i].style.width = "233px";
#  }
#  prodImageContainersWrappers = document.querySelectorAll(
#      ".product-image-container-55605  span.product-image-wrapper"
#  );
#  for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#      prodImageContainersWrappers[i].style.paddingBottom = "100%";
#  }</script> </a>
#  </div>
#  <div class="product details product-item-details">
#  <div class="price-wishlist-wrapper">
#  <div class="price-box price-final_price" data-price-box="product-id-55605" data-product-id="55605" data-role="priceBox">
#  <span class="price-container price-final_price tax weee">
#  <span class="price-wrapper" data-price-amount="8.35" data-price-type="finalPrice" id="product-price-55605"><span class="price">8,35 €</span></span>
#  </span>
#  </div> <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":55605,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  </div>
#  <div class="product-info-price-per">
#                                      7,95 €                                    /kg                                </div>
#  <div class="clear"></div>
#  <div class="product-item-inner">
#  <div class="product actions product-item-actions">
#  <div class="actions-primary">
#  <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
#  <input name="product" type="hidden" value="55605"/>
#  <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
#  <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
#  <div class="field qty">
#  <div class="decrease-button" onclick="var input = document.getElementById('qty-55605'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
#  <i aria-hidden="true" class="fa fa-minus-circle"></i>
#  </div>
#  <div class="control">
#  <input class="input-text qty" data-validate="null" id="qty-55605" maxlength="12" name="qty" title="Qté" type="number" value="1">
#  </input></div>
#  <div class="increase-button" onclick="var input = document.getElementById('qty-55605'); input.value = parseInt(input.value) + 1;">
#  <i aria-hidden="true" class="fa fa-plus-circle"></i>
#  </div>
#  </div>
#  <div class="actions-secondary" data-role="add-to-links">
#  <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":55605,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
#  <span>Ajouter à ma liste d’envie</span>
#  </a>
#  </div>
#  <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
#  <span>Ajouter</span>
#  </button>
#  </div>
#  </input></form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </li>]

# %% [markdown]
# What is the type of `items`?

# %% [markdown]
# > **Your Answer Here (Double click)**

# %% [markdown]
# ### Scraping one product information

# %% [markdown]
# Store the first item in a variable named `item`.

# %%
#your code here
item=items[0]
item
# Out:
# <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <p class="product name product-item-name">
# <a class="product-item-link" href="https://www.naturalia.fr/puree-pommes-fruit-rouge-705g">
#                                     Purée de Pommes et fruits rouges 705g Bio							</a>
# </p>
# <p class="product-item-brand">Naturalia</p>
# <div class="product-item-photo">
# <p class="banner discount percent-15">-15%</p>
# <a class="product photo" href="https://www.naturalia.fr/puree-pommes-fruit-rouge-705g" tabindex="-1">
# <span class="product-image-container product-image-container-58849">
# <span class="product-image-wrapper">
# <img alt="Purée de Pommes et fruits rouges 705g Bio" class="product-image-photo" height="233" loading="lazy" src="https://media.naturalia.fr/media/catalog/product/cache/c97961dbe2ef8ae9072b778469b58f9a/3/7/3700036907065.p1-1500j.jpg" width="233"/></span>
# </span>
# <style>.product-image-container-58849 {
#     width: 233px;
# }
# .product-image-container-58849 span.product-image-wrapper {
#     padding-bottom: 100%;
# }</style><script type="text/javascript">prodImageContainers = document.querySelectorAll(".product-image-container-58849");
# for (var i = 0; i < prodImageContainers.length; i++) {
#     prodImageContainers[i].style.width = "233px";
# }
# prodImageContainersWrappers = document.querySelectorAll(
#     ".product-image-container-58849  span.product-image-wrapper"
# );
# for (var i = 0; i < prodImageContainersWrappers.length; i++) {
#     prodImageContainersWrappers[i].style.paddingBottom = "100%";
# }</script> </a>
# </div>
# <div class="product details product-item-details">
# <div class="price-wishlist-wrapper">
# <div class="price-box price-final_price" data-price-box="product-id-58849" data-product-id="58849" data-role="priceBox">
# <span class="special-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">Prix Spécial</span>
# <span class="price-wrapper" data-price-amount="4.95" data-price-type="finalPrice" id="product-price-58849"><span class="price">4,95 €</span></span>
# </span>
# </span>
# <span class="old-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">Prix normal</span>
# <span class="price-wrapper" data-price-amount="5.85" data-price-type="oldPrice" id="old-price-58849"><span class="price">5,85 €</span></span>
# </span>
# </span>
# </div> <div class="actions-secondary" data-role="add-to-links">
# <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58849,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
# <span>Ajouter à ma liste d’envie</span>
# </a>
# </div>
# </div>
# <div class="product-info-price-per">
#                                     7,02 €                                    /kg                                </div>
# <div class="clear"></div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://www.naturalia.fr/naturalia_catalog/ajax/showPopup/" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="58849"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL25hdHVyYWxpYV9jYXRhbG9nL2FqYXgvc2hvd1BvcHVwLw,,"/>
# <input name="form_key" type="hidden" value="Cks9ai7ncOfcmY7B"> <div class="box-tocart">
# <div class="field qty">
# <div class="decrease-button" onclick="var input = document.getElementById('qty-58849'); input.value  = input.value &gt; 1 ? parseInt(input.value) - 1 : 1 ;">
# <i aria-hidden="true" class="fa fa-minus-circle"></i>
# </div>
# <div class="control">
# <input class="input-text qty" data-validate="null" id="qty-58849" maxlength="12" name="qty" title="Qté" type="number" value="1">
# </input></div>
# <div class="increase-button" onclick="var input = document.getElementById('qty-58849'); input.value = parseInt(input.value) + 1;">
# <i aria-hidden="true" class="fa fa-plus-circle"></i>
# </div>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label="Ajouter à ma liste d’envie" class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/www.naturalia.fr\/wishlist\/index\/add\/","data":{"product":58849,"uenc":"aHR0cHM6Ly93d3cubmF0dXJhbGlhLmZyL2NhdGFsb2dzZWFyY2gvcmVzdWx0Lz9xPWNvbXBvdGU,"}}' href="#" role="button" title="Ajouter à ma liste d’envie">
# <span>Ajouter à ma liste d’envie</span>
# </a>
# </div>
# <button class="action tocart primary" disabled="" title="Ajouter" type="submit">
# <span>Ajouter</span>
# </button>
# </div>
# </input></form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>

# %% [markdown]
# HTML can be tough to decipher when reading it in the notebook.
#
# Use your browser's console to identify the HTML tag storing the product information (name and url) of the first item. \
# Extract it with BeautifulSoup and store the results in a variable named `item_description`.

# %%
#find the tag that contains the product name and the url

item_description=item.find("a", {"class": "product-item-link"})
item_description
# Out:
# <a class="product-item-link" href="https://www.naturalia.fr/puree-pommes-fruit-rouge-705g">
#                                     Purée de Pommes et fruits rouges 705g Bio							</a>

# %% [markdown]
# Now extract the name and url from `item_description`and store them in two variables named `item_name` and `item_url`.

# %%
#store the product name

item_name= item_description.text.strip()
print(item_name)
# Out:
# Purée de Pommes et fruits rouges 705g Bio

# %%
#store the product url

item_url= item_description.attrs["href"]
print(item_url)
# Out:
# https://www.naturalia.fr/puree-pommes-fruit-rouge-705g

# %% [markdown]
# Repeat the same process to extract the price of the first item, and store it in a variable named `item_price`.

# %% [markdown]
# <details>
#     <summary>Hint 🔍</summary>
#
# You will be required to do some cleaning with the output, including:
#
# - get rid of the unnecessary characters (`strip()`and `replace()` methods can help)
# - change the data type
#
# </details>

# %%
#your code here

item_price=float(item.find("span",{"class":"price"}).text.strip().replace("\xa0€","").replace(",","."))
item_price
# Out:
# 4.95

# %% [markdown]
# ### Scraping all products information

# %% [markdown]
# We will now repeat the process to gather the information of all the products displayed on the page.
#
# By re-using your previous code, iterate over all the products and create a list of dictionaries containg all the products information (product name, price and url).
#
# Complete the following code and execute it.

# %%
import pandas as pd

# all products info
products = []

# iterate over items
for item in items:

    # to be completed
    item_description=item.find("a", {"class": "product-item-link"})
    
    item_name= item_description.text.strip()
    item_url= item_description.attrs["href"]
    item_price=float(item.find("span",{"class":"price"}).text.strip().replace("\xa0€","").replace(",","."))
    
    # product info
    product_info = {
        "product_name": item_name,
        "price": item_price,
        "url": item_url
    }

    # append product_info to products
    products.append(product_info)

df = pd.DataFrame(products)
df
# Out:
#                                         product_name  price  \
# 0          Purée de Pommes et fruits rouges 705g Bio   4.95
# 1                       Purée de cacahuètes 350g Bio   5.00
# 2                   Gourde de Cerise dès 6M 120g Bio   2.45
# 3                 Purée de pommes en gourde 120g Bio   1.45
# 4                Purée de carotte en gourde 120g Bio   1.55
# 5                 Purée de banane en gourde 120g Bio   1.45
# 6                Gourde de Mirabelle dès 6M 120g Bio   2.30
# 7                    Gourde de Pêche dès 4M 120g Bio   1.90
# 8                    Gourde de Figue dès 6M 120g Bio   2.30
# 9                Gourde de Framboise dès 6M 120g Bio   2.40
# 10                  Gourde d'Abricot dès 4M 120g Bio   1.90
# 11               Gourde de Myrtilles dès 4M 120g Bio   2.40
# 12                         Compote de Pêche 725G Bio   8.95
# 13                         Compote Rhubarbe 725G Bio   8.39
# 14                           Compote Fraise 315g Bio   5.30
# 15                 Compote de Pêche allégée 540g Bio   7.09
# 16                    Compote Pomme Vanille 660g Bio   5.35
# 17                    Compote Pommes Family 935g Bio   5.95
# 18                        Compote de poires 315G Bio   4.39
# 19               Compote de pomme & marrons 315G Bio   4.50
# 20           Compote de pomme & châtaigne 4x100G Bio   5.25
# 21      Purée de pommes sans sucres ajoutés 705G Bio   3.25
# 22  Purée Pommes Poires sans sucres ajoutés 705G Bio   3.99
# 23       Compote Pomme Poire Maxi Format 1.050kg Bio   8.35
#
#                                                   url
# 0   https://www.naturalia.fr/puree-pommes-fruit-ro...
# 1   https://www.naturalia.fr/puree-de-cacahuetes-350g
# 2           https://www.naturalia.fr/grde-cerise-120g
# 3    https://www.naturalia.fr/gourde-puree-pomme-120g
# 4   https://www.naturalia.fr/gourde-puree-carotte-...
# 5   https://www.naturalia.fr/gourde-puree-banane-120g
# 6       https://www.naturalia.fr/grde-mirabelles-120g
# 7             https://www.naturalia.fr/grd-peche-120g
# 8            https://www.naturalia.fr/grde-figue-120g
# 9        https://www.naturalia.fr/grde-framboise-120g
# 10         https://www.naturalia.fr/grde-abricot-120g
# 11       https://www.naturalia.fr/grde-myrtilles-120g
# 12  https://www.naturalia.fr/produit/compote-peche...
# 13  https://www.naturalia.fr/produit/compote-rhuba...
# 14  https://www.naturalia.fr/produit/compote-frais...
# 15  https://www.naturalia.fr/compote-peche-allegee...
# 16  https://www.naturalia.fr/produit/compote-pomme...
# 17  https://www.naturalia.fr/produit/compote-pomme...
# 18      https://www.naturalia.fr/compotes-poires-315g
# 19  https://www.naturalia.fr/compotes-pommes-marro...
# 20  https://www.naturalia.fr/compot-pomme-chataign...
# 21         https://www.naturalia.fr/puree-pommes-705g
# 22  https://www.naturalia.fr/puree-pommes-poires-705g
# 23  https://www.naturalia.fr/puree-pomme-poire-1-05kg

# %% [markdown]
# Congratulations! You just scraped your first web page using Python! 🤖

# %% [markdown]
# ---
#
# Did we scrape all the products though ?

# %% [markdown]
# > **Your Answer Here (Double click)**

# %% [markdown]
# ### Scraping all the pages

# %% [markdown]
# Use your web browser inspector to identify the HTML tag containing the URL for the next page. \
# Store this in a variable named `next_page_item`

# %%
# your code here
next_page_item = soup.find("a", {"class": "action next"})
next_page_item
# Out:
# <a class="action next" href="https://www.naturalia.fr/catalogsearch/result/index/?p=2&amp;q=compote" title="Suivant">
# <i aria-hidden="true" class="fa fa-chevron-circle-right"></i>
# </a>

# %% [markdown]
# Now extract the URL from it and store it in a variable named `next_page_url`.

# %%
#your code here
next_page_url = next_page_item.attrs["href"]
next_page_url
# Out:
# 'https://www.naturalia.fr/catalogsearch/result/index/?p=2&q=compote'

# %% [markdown]
# Now try to repeat the `next_page_item`instructions **on the last page**. Does it work ?

# %%
# your code here
response=requests.get("https://www.naturalia.fr/catalogsearch/result/index/?p=5&q=compote")
soup = BeautifulSoup(response.text,"html.parser")

next_page_item = soup.find("a", {"class": "action next"})
print(next_page_item)
# Out:
# None

# %% [markdown]
# > **Your Answer Here (Double click)**

# %% [markdown]
# There is no "Next page" button on the last page (obviously). Therefore, when we try to locate it, the`find()` method outputs a None value.
#
# We can actually use that to our advantage in a `while`loop !

# %% [markdown]
# ---
#
# **Hard Mode**
#
# By re-using all of the previous steps, create a final function that will take a `search_term` as a parameter (like we did with "compote") and will return a DataFrame containing products information from all the pages.

# %% [markdown]
# <details>
#     <summary>Hint 🔍 </summary>
#
# You can use a while loop to iterate over pages until there is no next page anymore.
#
# </details>

# %%
def naturalia_web_scraper(search_term):
    
    url = "https://www.naturalia.fr/catalogsearch/result/?q=" + search_term
    
    next_page = True
    
    #all products info
    
    products=[]
    
    while(next_page): #as long as there is a next page, the loop will iterate
        
        #get items
        #your code here
        
        response=requests.get(url)
        soup=BeautifulSoup(response.text,"html.parser")
        
        items=soup.find_all('li',{"class":"item product product-item"})
        
        # iterate over items
        for item in items:
            #your code here
            
            item_description=item.find("a", {"class": "product-item-link"})
    
            item_name= item_description.text.strip()
            item_url= item_description.attrs["href"]
            item_price=float(item.find("span",{"class":"price"}).text.strip().replace("\xa0€","").replace(",","."))

            # product info
            product_info = {
                "product_name": item_name,
                "price": item_price,
                "url": item_url
            }

            # append product_info to products
            products.append(product_info)
            
            # test for next page
            #your code here
            next_page_item = soup.find("li", {"class": "item pages-item-next"})
            
            if(next_page_item): #equivalent to if next_page_item != None
                
                next_page_url = next_page_item.find("a", {"class": "action next"}).get("href")
                url = next_page_url
            
            else:
                next_page = False
    
    # combine all products in a single DataFrame
    df = pd.DataFrame(products)
    
    return df


#test your function

naturalia_web_scraper("compote")
# Out:
#     price                                       product_name  \
# 0    4.95          Purée de Pommes et fruits rouges 705g Bio
# 1    5.00                       Purée de cacahuètes 350g Bio
# 2    2.45                   Gourde de Cerise dès 6M 120g Bio
# 3    1.45                 Purée de pommes en gourde 120g Bio
# 4    1.55                Purée de carotte en gourde 120g Bio
# ..    ...                                                ...
# 91   4.20  Purée Pommes Myrtille sans sucres ajoutés 360g...
# 92   4.65  Purée Mangue Rhubarbe sans sucres ajoutés 350g...
# 93   3.79    Purée Pomme Cassis sans sucres ajoutés 360g Bio
# 94   3.89    Purée Pommes Coing sans sucres ajoutés 360g Bio
# 95   3.16      Petit pot de Pomme & Mangue dès 4M 2x130g Bio
#
#                                                   url
# 0   https://www.naturalia.fr/puree-pommes-fruit-ro...
# 1   https://www.naturalia.fr/puree-de-cacahuetes-350g
# 2           https://www.naturalia.fr/grde-cerise-120g
# 3    https://www.naturalia.fr/gourde-puree-pomme-120g
# 4   https://www.naturalia.fr/gourde-puree-carotte-...
# ..                                                ...
# 91  https://www.naturalia.fr/produit/puree-pom-myr...
# 92  https://www.naturalia.fr/puree-mangue-rhubarbe...
# 93  https://www.naturalia.fr/produit/puree-pom-cas...
# 94  https://www.naturalia.fr/produit/puree-pom-coi...
# 95  https://www.naturalia.fr/pot-bb-pom-mangue-2x1...
#
# [96 rows x 3 columns]

# %% [markdown]
# Congratulations ! 🎉

# %% [markdown]
# ## Bonus: Scraping Walmart ?

# %% [markdown]
# Imagine we want to scrape product information from [this url](https://www.walmart.ca/parcourir/epicerie/collations-bonbons/coupes-compote-pommes-puree-fruits/10019-6000194328523-6000195492964) now.
#
# Run the following line of code.

# %%
url = "https://www.walmart.ca/fr/browse/epicerie/collations-bonbons/coupes-compote-pommes-puree-fruits/10019_6000194328523_6000195492964"

response = requests.get(url)
response.text
# Out:
# '<!DOCTYPE html>\n<html lang=en><head> <meta charset=utf-8 /> <meta name=viewport content="width=device-width, initial-scale=1"/> <title>Verify Your Identity</title>  <script>function getUrlVars(){var vars={};var parts=window.location.href.replace(/[?&]+([^=&]+)=([^&]*)/gi,function(m,key,value){vars[key]=value;});return vars;}\nfunction getUrlParam(parameter,defaultvalue){var urlparameter=defaultvalue;if(window.location.href.indexOf(parameter)>-1){urlparameter=getUrlVars()[parameter];}\nreturn urlparameter;}\nfunction sanitizeUuid(uuid){var regex=new RegExp("^\\\\b[0-9a-f]{8}\\\\b-[0-9a-f]{4}-[0-9a-f]{4}-[0-9a-f]{4}-\\\\b[0-9a-f]{12}\\\\b$","g");var match=regex.exec(uuid);return match!=null?uuid:"";}\nfunction addBlockID(){var blockId=sanitizeUuid(getUrlParam(\'uuid\',\'\'));document.getElementById("blockId1").innerHTML="ID: "+blockId;}\nfunction getCookie(name){var cookieArr=document.cookie.split(";");for(var i=0;i<cookieArr.length;i++){var cookiePair=cookieArr[i].split("=");if(name==cookiePair[0].trim()){return decodeURIComponent(cookiePair[1]);}}\nreturn null;}</script> <script id=launchScript></script> <script type="text/javascript">window.walmart=window.walmart||{};window.walmart.analytics=window.walmart.analytics||{};window.walmart.analytics.dataLayer={channel:"Bot Page",host:window.location.host,pageName:"Bot Protection Page",pageType:"Bot Protection Page",language:(window.language||"en").indexOf("fr")==="0"?"French":"English",persistentID:getCookie("walmart.id"),referrer:document.referrer};var launchScript=document.getElementById("launchScript");launchScript.async=true;launchScript.onload=function(){if(window._satellite&&window._satellite.track){window._satellite.track("pageLoadComplete");}}\nlaunchScript.src="//assets.adobedtm.com/launch-ENb669ecb013cf4aa89de0580c69e13c1a.min.js";</script>\n<style>\n@import url(https://fonts.googleapis.com/css?family=Roboto:400,500&display=swap);html,\nbody{font-family:Roboto,Arial,Helvetica,sans-serif;font-style:normal;font-weight:400;margin:0;padding:0;color:#000}\na{color:#c5c5c5;text-decoration:none}\nheader{margin:40px 10%}\n.container{align-items:center;display:flex;flex:1;justify-content:space-between;flex-direction:column}\n.container>div{width:100%;display:flex;justify-content:center}\n.container>div>div{width:80%}\n.page-title-wrapper{flex-grow:2}\n.page-title{flex-direction:column-reverse}\n.content-wrapper{flex-grow:5}\n.content{flex-direction:column}\n#message{padding-bottom:2em}\n#px-captcha > p{color:#C00D1E}\n@media (min-width: 768px){\nhtml,\nbody{height:100%}\n}\n</style></head> <body> <header> <svg height=47.016 viewBox="0 0 188.414 47.016" width=188.41> <path d="M.942 10.272s4.639 19.006 5.379 22.09c.864 3.602 2.42 4.927 6.91 4.033l2.895-11.784c.735-2.927 1.227-5.013 1.699-7.99h.083c.331 3.006.803 5.072 1.407 8 0 0 1.18 5.35 1.783 8.16.606 2.809 2.29 4.579 6.687 3.615l6.9-26.122h-5.571l-2.356 11.294c-.633 3.287-1.208 5.856-1.651 8.863h-.079c-.403-2.977-.915-5.444-1.559-8.647l-2.453-11.51H15.21l-2.624 11.22c-.744 3.41-1.44 6.163-1.881 9.068h-.08a318.737 318.737 0 0 0-1.71-9.497S7.359 13.04 6.812 10.274H.943zm53.115 0v26.122h5.305V10.27h-5.305zm74.713 0v19.27c0 2.658.5 4.52 1.57 5.656.934.995 2.474 1.64 4.319 1.64 1.568 0 3.111-.298 3.838-.57l-.068-4.145a8.065 8.065 0 0 1-2.015.24c-1.807 0-2.413-1.157-2.413-3.543v-7.373h4.62v-4.998H134v-6.177h-5.231zm-86.567 6.055c-3.297 0-5.914.926-7.34 1.75l1.043 3.575c1.306-.823 3.384-1.504 5.353-1.504 3.258-.009 3.791 1.842 3.791 3.03v.28c-7.1-.01-11.586 2.447-11.586 7.455 0 3.058 2.283 5.924 6.254 5.924 2.444 0 4.488-.975 5.713-2.537h.12s.811 3.392 5.28 2.095c-.235-1.411-.311-2.917-.311-4.73v-6.978c0-4.448-1.899-8.36-8.317-8.36zm31.732 0c-3.32 0-4.811 1.683-5.716 3.11h-.078V16.77h-5.063v19.625h5.333V24.886c0-.54.062-1.11.25-1.606.442-1.16 1.52-2.515 3.241-2.515 2.152 0 3.16 1.82 3.16 4.445v11.185h5.326V24.747c0-.515.071-1.136.223-1.591.438-1.318 1.6-2.39 3.2-2.39 2.181 0 3.228 1.787 3.228 4.876v10.753h5.331V24.837c0-6.096-3.095- ...

# %% [markdown]
# We cannot use BeautifulSoup, because Walmart is using an anti Web Scraping system, which messes with the HTML parsing.
#
# We would need some advanced scraping libraries such as [Selenium](https://www.selenium.dev/) to proceed (more on that during the recap).
